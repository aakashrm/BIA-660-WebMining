# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.read_edgelist("web-EPA.edges",create_using = nx.Graph()) 
print(nx.info(G))
nx.draw(G,with_labels=True)
plt.show()
pgr=nx.pagerank(G,alpha = 0.85)
print(pgr) 
print(nx.is_directed(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 4271
# Number of edges: 8909
# Average degree:   4.1719
# ...
